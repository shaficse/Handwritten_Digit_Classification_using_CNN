# %%
# Import Tensorflow 2.0
# %tensorflow_version 2.x
import tensorflow as tf 
import matplotlib.pyplot as plt
import numpy as np
import random
from tqdm import tqdm
import data_loader.util as util

# Check that we are using a GPU, if not switch runtimes
#   using Runtime > Change Runtime Type > GPU
# assert len(tf.config.list_physical_devices('GPU')) > 0

# %%
#Downloading data from tf keras dataset
mnist_data = tf.keras.datasets.mnist.load_data()
(train_images, train_labels), (test_images, test_labels)= mnist_data
print(train_images.shape,train_labels.shape,test_images.shape,test_labels.shape)
# Out:
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)

# %%
#Data processing for model feeding
train_images = (np.expand_dims(train_images,axis = -1)/255.).astype(np.float32)
train_labels = (train_labels).astype(np.float64)

# %%
print(type(test_labels[0]),type(test_labels[0]))
# Out:
# <class 'numpy.uint8'> <class 'numpy.uint8'>

# %%
test_images = (np.expand_dims(test_images,axis = -1)/255.).astype(np.float32)
test_labels = (test_labels).astype(np.float64)
print(train_images.shape,train_labels.shape,test_images.shape,test_labels.shape)
# Out:
# (60000, 28, 28, 1) (60000,) (10000, 28, 28, 1) (10000,)

# %%
print(type(test_labels[0]),type(test_labels[0]))
# Out:
# <class 'numpy.float64'> <class 'numpy.float64'>

# %%
print(train_images.shape, train_labels.shape,test_images.shape, test_labels.shape)
# Out:
# (60000, 28, 28, 1) (60000,) (10000, 28, 28, 1) (10000,)

# %%
util.visualize_data(train_images,train_labels,number_data_to_show=81)

# %%
import model_loader.model as m_loader
import model_loader.configure as model_config

# %%
model = m_loader.build_cnn_model()

# %%
import os
checkpoint_path = "./training_1/Epoch_{epoch:02d}_train_loss_{loss}_Val_loss{val_loss}.hdf5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
model.compile(optimizer=model_config.optimizer, loss=model_config.loss, metrics=model_config.metrics)

# %%
model.fit(train_images, train_labels, batch_size=model_config.BATCH_SIZE, epochs=5,validation_data=(test_images, test_labels),
          callbacks=[cp_callback])
# Out:
# Epoch 1/5
# 938/938 [==============================] - 16s 17ms/step - loss: 2.3107 - accuracy: 0.1038 - val_loss: 2.3068 - val_accuracy: 0.1010
# Epoch 2/5
# 938/938 [==============================] - 15s 16ms/step - loss: 2.3101 - accuracy: 0.1061 - val_loss: 2.3035 - val_accuracy: 0.1135
# Epoch 3/5
# 938/938 [==============================] - 15s 16ms/step - loss: 2.3101 - accuracy: 0.1031 - val_loss: 2.3073 - val_accuracy: 0.1135
# Epoch 4/5
# 938/938 [==============================] - 15s 16ms/step - loss: 2.3104 - accuracy: 0.1022 - val_loss: 2.3057 - val_accuracy: 0.1135
# Epoch 5/5
# 938/938 [==============================] - 15s 16ms/step - loss: 2.3098 - accuracy: 0.1045 - val_loss: 2.3046 - val_accuracy: 0.0982

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test Accuracy',test_loss)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.3046 - accuracy: 0.0982
# Test Accuracy 2.304644823074341

# %%
checkpoint_path="training_1/Epoch_02_train_loss_2.3100504875183105_Val_loss2.303476095199585.hdf5"

# %%
new_model = tf.keras.models.load_model(checkpoint_path)

# %%
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 24)        240
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 24)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 36)        7812
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 36)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 900)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               115328
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 124,670
# Trainable params: 124,670
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_loss, test_acc = model_ev.evaluate(test_images, test_labels)
print('Test Accuracy',test_loss)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.3087 - accuracy: 0.1047
# Test Accuracy 2.3086607456207275
